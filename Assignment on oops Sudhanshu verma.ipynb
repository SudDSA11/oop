# %%
#1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
#that overrides the speak() method to print "Bark!".
#parent class
class Animal:
    def speak(self):
        print("The animal makes a sound.")
        generic_animal = Animal()
        generic_animal.speak()
# Child class
class Dog(Animal):
    def speak(self):
        print("Bark!")
dog = Dog()
dog.speak()
# Out:
# Bark!

# %%
#2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
#from it and implement the area() method in both.
from abc import ABC, abstractmethod
import math
# Abstract base class
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass
# Derived class: Circle
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius
    def area(self):
        return math.pi * self.radius ** 2
# Derived class: Rectangle
class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height
    def area(self):
        return self.width * self.height
# Create instances and display areas
circle = Circle(4)
rectangle = Rectangle(3, 2)
print(f"Area of circle: {circle.area():.2f}")
print(f"Area of rectangle: {rectangle.area()}")
# Out:
# Area of circle: 50.27
# Area of rectangle: 6

# %%
#3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
# and further derive a class ElectricCar that adds a battery attribute.
# Base class
class Vehicle:
    def __init__(self, vehicle_type):
        self.type = vehicle_type

    def display_type(self):
        print(f"Vehicle type: {self.type}")

# Derived class
class Car(Vehicle):
    def __init__(self, vehicle_type, brand):
        super().__init__(vehicle_type)
        self.brand = brand
    def display_brand(self):
        print(f"Car brand: {self.brand}")

# Further derived class
class ElectricCar(Car):
    def __init__(self, vehicle_type, brand, battery_capacity):
        super().__init__(vehicle_type, brand)
        self.battery = battery_capacity
    def display_battery(self):
        print(f"Battery capacity: {self.battery} kWh")

# Create an object of ElectricCar
tesla = ElectricCar("Electric", "Tesla", 75)
# Display information
tesla.display_type()
tesla.display_brand()
tesla.display_battery()
# Out:
# Vehicle type: Electric
# Car brand: Tesla
# Battery capacity: 75 kWh

# %%
#4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
# Sparrow and Penguin that override the fly() method.
# Base class
class Bird:
    def fly(self):
        print("Some bird is flying.")

# Derived class: Sparrow
class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high in the sky.")
# Derived class: Penguin
class Penguin(Bird):
    def fly(self):
        print("Penguins can't fly, but they swim well.")
# Function demonstrating polymorphism
def bird_flight(bird):
    bird.fly()
# Create instances
sparrow = Sparrow()
penguin = Penguin()
# Demonstrate polymorphism
bird_flight(sparrow)
bird_flight(penguin)
# Out:
# Sparrow flies high in the sky.
# Penguins can't fly, but they swim well.

# %%
#5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
# balance and methods to deposit, withdraw, and check balance.
class BankAccount:
    def __init__(self, initial_balance=0):
        self.__balance = initial_balance  # Private attribute

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: ${amount}")
        else:
            print("Deposit amount must be positive.")

    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrew: ${amount}")
        else:
            print("Insufficient funds or invalid amount.")

    def check_balance(self):
        print(f"Current balance: ${self.__balance}")

# Create an instance of BankAccount
account = BankAccount(100)

# Demonstrate the methods
account.check_balance()
account.deposit(50)
account.check_balance()
account.withdraw(70)
account.check_balance()
account.withdraw(100)
# Out:
# Current balance: $100
# Deposited: $50
# Current balance: $150
# Withdrew: $70
# Current balance: $80
# Insufficient funds or invalid amount.

# %%
#6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
# and Piano that implement their own version of play().
# Base class
class Instrument:
    def play(self):
        print("An instrument is being played.")

# Derived class: Guitar
class Guitar(Instrument):
    def play(self):
        print("Strumming the guitar.")

# Derived class: Piano
class Piano(Instrument):
    def play(self):
        print("Playing the piano.")

# Function to demonstrate runtime polymorphism
def start_playing(instrument):
    instrument.play()
# Create objects
guitar = Guitar()
piano = Piano()
# Demonstrate runtime polymorphism
start_playing(guitar)
start_playing(piano)
# Out:
# Strumming the guitar.
# Playing the piano.

# %%
#7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static
# method subtract_numbers() to subtract two numbers.
class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

# Example usage
sum_result = MathOperations.add_numbers(5, 5)
diff_result = MathOperations.subtract_numbers(12, 5)

print(f"Sum: {sum_result}")
print(f"Difference: {diff_result}")
# Out:
# Sum: 10
# Difference: 7

# %%
#8. Implement a class Person with a class method to count the total number of persons created
class Person:
    count = 0  # Class variable to keep track of the number of persons

    def __init__(self, name):
        self.name = name
        Person.count += 1

    @classmethod
    def total_persons(cls):
        return cls.count
        # Example usage
p1 = Person("ravi")
p2 = Person("sunil")
print(f"Total persons created: {Person.total_persons()}")
# Out:
# Total persons created: 2

# %%
#9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the
# fraction as "numerator/denominator"
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

# Example usage
f1 = Fraction(3, 4)
f2 = Fraction(7, 2)

print(f1)
print(f2)
# Out:
# 3/4
# 7/2

# %%
#10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
# vectors.
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    # Overloading the + operator
    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"Vector({self.x}, {self.y})"

# Example usage
v1 = Vector(2, 3)
v2 = Vector(4, 5)
v3 = v1 + v2

print(v3)
# Out:
# Vector(6, 8)

# %%
#11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
# {name} and I am {age} years old."
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# Example usage
person1 = Person("sandeep", 20)
person1.greet()
# Out:
# Hello, my name is sandeep and I am 20 years old.

# %%
#12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute
# the average of the grades.
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades  # Expecting a list of numbers

    def average_grade(self):
        if not self.grades:
            return 0  # Avoid division by zero if grades list is empty
        return sum(self.grades) / len(self.grades)

# Example usage
student1 = Student("sunil", [45, 78, 78, 92])
print(f"{student1.name}'s average grade: {student1.average_grade():.2f}")
# Out:
# sunil's average grade: 73.25

# %%
#13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
# area.
class Rectangle:
    def __init__(self):
        self.width = 0
        self.height = 0

    def set_dimensions(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

# Example usage
rect = Rectangle()
rect.set_dimensions(6, 17)
print(f"Area of rectangle: {rect.area()}")
# Out:
# Area of rectangle: 102

# %%
#14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
# and hourly rate. Create a derived class Manager that adds a bonus to the salary.
# Base class
class Employee:
    def __init__(self, name, hours_worked, hourly_rate):
        self.name = name
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate

# Derived class
class Manager(Employee):
    def __init__(self, name, hours_worked, hourly_rate, bonus):
        super().__init__(name, hours_worked, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self):
        base_salary = super().calculate_salary()
        return base_salary + self.bonus

# Example usage
emp = Employee("Arjun", 50, 15)
print(f"{emp.name}'s salary: ${emp.calculate_salary()}")
mgr = Manager("Bimal", 40, 445, 100)
print(f"{mgr.name}'s salary: ${mgr.calculate_salary()}")
# Out:
# Arjun's salary: $750
# Bimal's salary: $17900

# %%
#15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
# calculates the total price of the product.
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

# Example usage
product1 = Product("Television", 900, 3)
print(f"Total price for {product1.quantity} {product1.name}(s): ${product1.total_price()}")
# Out:
# Total price for 3 Television(s): $2700

# %%
#16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
# implement the sound() method.
from abc import ABC, abstractmethod

# Abstract base class
class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

# Derived class: Cow
class Cow(Animal):
    def sound(self):
        return "Moo"

# Derived class: Sheep
class Sheep(Animal):
    def sound(self):
        return "Baa"

# Example usage
cow = Cow()
sheep = Sheep()
print(f"Cow says: {cow.sound()}")
print(f"Sheep says: {sheep.sound()}")
# Out:
# Cow says: Moo
# Sheep says: Baa

# %%
#17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
# returns a formatted string with the book's details.
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"'{self.title}' by {self.author} (Published in {self.year_published})"
        # Example usage
book1 = Book("The Private Life of an Indian Prince", "Mukul Raj Anand", 1953)
print(book1.get_book_info())
# Out:
# 'The Private Life of an Indian Prince' by Mukul Raj Anand (Published in 1953)

# %%
#18. Create a class House with attributes address and price. Create a derived class Mansion that adds an
# attribute number_of_rooms.
# Base class
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

    def display_info(self):
        return f"Address: {self.address}, Price: ${self.price}"

# Derived class
class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

    def display_info(self):
        base_info = super().display_info()
        return f"{base_info}, Rooms: {self.number_of_rooms}"

# Example usage
mansion1 = Mansion("1/657 Ambalika lane", 454000, 10)
print(mansion1.display_info())
# Out:
# Address: 1/657 Ambalika lane, Price: $454000, Rooms: 10

# %%
# 3. What is Object-Oriented Programming (OOP)?
'''
oops is a programming based on the concepts of object which are instances of classes.
It focuses on organising software design around data(object) and the functions (methods) that operate on that data.
'''
# Out:
# '\noops is a programming based on the concepts of object which are instances of classes. \nIt focuses on organising software design around data(object) and the functions (methods) that operate on that data.\n'

# %%
# 2. What is a class in OOPs?
'''
 a class is a blueprint or template for creating objects. It defines the attributes (also known as fields or properties) and methods (functions)
 that the objects created from the class will have.
'''

# %%
# 3. What is an object in OOP?
'''
An object is a self-contained unit that combines data and the functions (methods) that operate on that data.
'''

# %%
# 4.  What is the difference between abstraction and encapsulation?
'''
Abstraction is about hiding the complexity and only showing the relevant details.
The user just calls press_power_button() without knowing the internal circuitry.
They know what it does, not how it does it.

Encapsulation is about protecting the internal state of an object and restricting access to it.
The balance is hidden (__balance) and only accessed through controlled methods.
This encapsulates the data to avoid direct manipulation.
'''

# %%
# 5. What are dunder methods in Python?
'''
Dunder methods are built-in hooks that allow you to define how objects of your class behave with operators, functions, and language features (like printing or indexing).
They let you customize object behavior in a very "Pythonic" way.
In Python, dunder methods (short for "double underscore" methods, also called magic methods)
are special methods with names that start and end with double underscores, like __init__, __str__, __len__, etc.
'''

# %%
# 6. Explain the concept of inheritance in OOP?
'''
Inheritance is a core concept in OOP that allows one class (called a child or subclass) to inherit attributes and methods from another class (called a parent or superclass).
This promotes code reuse, hierarchy, and extensibility.
'''

# %%
# 7. What is polymorphism in OOP?
'''
In OOP, it allows objects of different classes to be treated as objects of a common superclass, and lets the same interface (method or operator)
behave differently depending on the object.
'''

# %%
# 8. How is encapsulation achieved in Python?
'''
Encapsulation in Python is achieved by restricting access to the internal data (attributes) and methods of a class.
This helps protect the object’s internal state and allows controlled interaction through public methods (getters/setters).
'''

# %%
# 9. What is a constructor in Python?
'''
In Python, a constructor is a special method that gets called automatically when a new object is created from a class.
It’s used to initialize the object’s attributes (i.e., set up its state).
'''

# %%
# 10. What are class and static methods in Python?
'''
In Python, class methods and static methods are two special types of methods that behave differently from regular instance methods.
They are defined using decorators: @classmethod and @staticmethod.
'''

# %%
# 11. What is method overloading in Python?
'''
Method overloading means having multiple methods in the same class with the same name but different parameters (different number or types of arguments).
This allows a method to behave differently based on the arguments passed.
'''

# %%
# 12.  What is method overriding in OOP?
'''
Method overriding happens when a child class provides its own version of a method that is already defined in its parent class.
The child’s method replaces (or overrides) the parent’s method when called on a child object.
'''

# %%
# 13. What is a property decorator in Python?
'''
The property decorator is a Pythonic way to define getter methods in a class, allowing you to access methods like attributes (without calling them with parentheses).
It helps you encapsulate instance variables while providing a clean syntax to get (and set) values.
'''

# %%
# 14. Why is polymorphism important in OOP?
'''
Polymorphism lets you write generic code that can work with objects of different classes as long as they follow the same interface (e.g., have the same method names).
You can reuse the same function or method to operate on objects of various types.
Changes to specific behaviors are confined to individual subclasses, without affecting the rest of the program.
The program decides at runtime which method to call based on the actual object, not just the declared type.
'''

# %%
# 15. What is an abstract class in Python?
'''
An abstract class is a class that cannot be instantiated directly and is designed to be a base class for other classes.
It usually contains one or more abstract methods — methods declared but not implemented in the abstract class.
Abstract classes define a common interface for subclasses, forcing them to implement certain methods.
'''

# %%
# 16. What are the advantages of OOP?
'''
key advantages of Object-Oriented Programming (OOP):
1-Modularity
2-Reusability
3-Encapsulation
4-Abstraction
5-Polymorphism
6-Real-world Modeling
7-Improved Productivity
'''

# %%
# 17. What is the difference between a class variable and an instance variable?
'''
Class variables are shared among all instances of a class, while instance variables are unique to each instance.
'''

# %%
# 18. What is multiple inheritance in Python?
'''
Multiple inheritance means a class can inherit from more than one parent class.
This lets a child class combine behaviors and attributes from multiple base classes.
'''

# %%
# 19. Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python?
'''
__repr__ :	Produce an official string representation of the object — ideally one that can be used to recreate the object (or at least detailed).
Called by repr() and in the interactive interpreter.
_str__	Produce a nice/readable string representation — user-friendly, meant to be informative but not necessarily unambiguous.
Called by str() and print()
'''

# %%
# 20. What is the significance of the ‘super()’ function in Python?
'''
super() returns a proxy object that allows you to call methods from a parent (super) class.
It helps you access and extend parent class functionality in child classes, especially in the presence of multiple inheritance.
'''

# %%
# 21. What is the significance of the __del__ method in Python?
'''
The __del__ method is a destructor in Python.
It is called when an object is about to be destroyed, i.e., when its reference count drops to zero and it’s about to be garbage collected.
It allows you to define cleanup actions, like closing files, releasing resources, or logging before the object is removed.
'''

# %%
# 22. What is the difference between @staticmethod and @classmethod in Python?
'''
@staticmethod
	Not bound to class or instance, can be called without creating an object, Takes no mandatory first parameter (self or cls not passed),
  Cannot access instance (self) or class (cls) data directly, 	Utility functions related to the class but independent of class/instance state
@classmethod
  Bound to the class, not the instance, Takes cls as the first parameter (the class itself), Can access/modify class state via cls,
  Factory methods or methods that modify class state, Usually called on class, but can be called on instance as well.
'''

# %%
# 23. How does polymorphism work in Python with inheritance?
'''
Polymorphism means that a common interface (like a method name) can work differently depending on the object's actual class — even if all those classes share a common parent.
When you inherit from a base class, you can override its methods in subclasses, and when you call those methods on a base class reference (or variable),
Python will automatically call the correct subclass method at runtime.
'''

# %%
# 24. What is method chaining in Python OOP?
'''
Method chaining is a technique where you call multiple methods in a single line, one after another, on the same object.
Each method returns the object itself (self), so the next method can be called directly.
'''

# %%
# 25. What is the purpose of the __call__ method in Python?
'''
The __call__ method in Python is a special dunder method that lets you make an instance of a class callable like a function.

'''
